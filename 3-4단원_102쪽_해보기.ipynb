# %% [markdown]
# [해보기1] print() 함수를 사용하여 여러 줄로 출력하기

# %% [markdown]
# 프로그램1

# %%
print('문자열')
print('여러 줄')
# Out:
# 문자열
# 여러 줄

# %% [markdown]
# 프로그램2

# %%
#큰 따옴표 3개를 사용하여 여러 줄로 출력하는 프로그램
print("""문자열
여러 줄""")
# Out:
# 문자열
# 여러 줄

# %% [markdown]
# 프로그램3

# %%
#이스케이프 문자를 사용하여 여러 줄로 출력하는 프로그램
print('문자열\n여러 줄')
# Out:
# 문자열
# 여러 줄
