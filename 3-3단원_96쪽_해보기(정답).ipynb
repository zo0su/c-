# %% [markdown]
# [해보기3] 자료형 산술 연산자

# %% [markdown]
# 방법1

# %%
r, pi = 3, 3.14
area = r ** 2 * pi
print('원의 넓이:', area)

# %% [markdown]
# 방법2

# %%
r = 3
pi = 3.14
area = r ** 2 * pi
print('원의 넓이:', area)
