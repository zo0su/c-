# %% [markdown]
# [탐구활동] 도서 관리 프로그램 작성하기

# %%
# 사용자에게 입력받은 내용을 파일에 쓰기
title = input('책 제목을 입력하세요:')
writer = input('책의 저자를 입력하세요:')
price = int(input('책의 가격을 입력하세요:'))
f = open('Book.csv', 'a')
f.write(title+', '+writer+', '+str(price)+'\n')
# f.write(f'{title}, {writer}, {price}\n')
f.close()

# 파일의 전체 내용 출력하기
f = open('Book.csv', 'r')
data = f.read() # 파일 전체 읽기
print(data)
# Out:
# 책 제목을 입력하세요:메밀꽃 필 무렵
# 책의 저자를 입력하세요:이효석
# 책의 가격을 입력하세요:1100
# 메밀꽃 필 무렵, 이효석, 1100
