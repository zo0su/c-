# %% [markdown]
# [탐구활동] 기초 대사량 계산 프로그램 작성하기

# %%
print('<기초대사량 계산 프로그램>')
# 체중, 키, 나이를 변수에 대입하기
weight = 52.5
height = 163
age = 18

# 기초대사량 계산하기
BMR = 665.1 + (9.56 * weight) + (1.85 * height) - (4.68 * age)

# 출력하기
print('체중', weight, '키', height, '나이', age, '인 여성의 기초대사량:', BMR)
# Out:
# <기초대사량 계산 프로그램>
# 체중 52.5 키 163 나이 18 인 여성의 기초대사량: 1384.31
