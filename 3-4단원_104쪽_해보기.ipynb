# %% [markdown]
# [해보기2] 반지름을 입력받아 원의 넓이 출력하기

# %% [markdown]
# 방법1

# %%
r = float(input('원의 반지름: '))
pi = 3.14
area = r**2*pi
print('원의 넓이:', area)
# Out:
# 원의 반지름: 2.8
# 원의 넓이: 24.6176

# %% [markdown]
# 방법2

# %%
r = float(input('원의 반지름: '))
pi = 3.14
area = r ** 2 * pi
print(f'원의 넓이: {area}')
# Out:
# 원의 반지름: 2.8
# 원의 넓이: 24.6176
